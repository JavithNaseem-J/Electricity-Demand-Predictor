# %%
import os
import sys

# %%
pwd('../')
# Out:
# 'f:\\Electricity-Demand-Predictor\\notebooks'

# %%
os.chdir('../')

# %%
sys.path.append(os.path.join(os.getcwd(), "src"))

# %%
from electron.utils.helpers import *
from electron.constants import *

# %%
from pathlib import Path
from dataclasses import dataclass
from datetime import datetime, timedelta

# %%
@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_api: str
    raw_data_path: Path
    data_file: Path
    start_date: str
    end_date: str

# %%
class ConfigurationManager:
    def __init__(self,config_filepath=CONFIG_PATH,
                 params_filepath=PARAMS_PATH,
                 schema_filepath=SCHEMA_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion
        params = self.params.dates

        data_ingestion_config = DataIngestionConfig(
            root_dir=Path(config.root_dir),
            source_api=config.source_api,
            raw_data_path=Path(config.raw_data_path),
            data_file=Path(config.data_file),
            start_date=params.start_date,
            end_date=params.end_date
        )

        return data_ingestion_config

# %%
import pandas as pd
import requests
import json
from electron import logger
from sklearn.preprocessing import LabelEncoder
from pathlib import Path



class DataIngestion:
    def __init__(self, config: DataIngestionConfig):
        self.config = config
        self.label_encoder = LabelEncoder()
        
        # Create directories if they don't exist
        self.config.raw_data_path.mkdir(parents=True, exist_ok=True)
        self.config.data_file.parent.mkdir(parents=True, exist_ok=True)
        
        logger.info(f"DataIngestion initialized with config: {config}")

    def _get_api_url(self, year, month, day):
        """
        Generate API URL and parameters for fetching electricity data.
        
        Args:
            year (int): Year
            month (int): Month
            day (int): Day
            
        Returns:
            tuple: (url, params) for API request
        """
        return (
            "https://api.eia.gov/v2/electricity/rto/region-sub-ba-data/data/"
        ), {
            "frequency": "hourly",
            "data[0]": "value",
            "sort[0][column]": "period",
            "sort[0][direction]": "desc",
            "facets[parent][0]": "NYIS",
            "offset": 0,
            "length": 5000,
            "start": f"{year}-{month:02d}-{day:02d}",
            "end": (datetime(year, month, day) + timedelta(days=1)).strftime("%Y-%m-%d"),
            "api_key": 'dqRq8VpXSoyUrCbrPhuYFxGl6Rul9kmVcRshZ98c'
        }

    def _fetch_and_save_json(self, year, month, day) -> Path:
        """
        Fetch data from API and save as JSON file.
        
        Args:
            year (int): Year
            month (int): Month
            day (int): Day
            
        Returns:
            Path: Path to saved JSON file or None if failed
        """
        url, params = self._get_api_url(year, month, day)
        try:
            logger.info(f"Fetching data for {year}-{month:02d}-{day:02d}")
            response = requests.get(url, params=params)
            response.raise_for_status()
            data = response.json()

            save_path = self.config.raw_data_path / f"hourly_demand_{year}-{month:02d}-{day:02d}.json"
            with open(save_path, 'w') as f:
                json.dump(data, f, indent=4)

            logger.info(f"Saved data to {save_path}")
            return save_path
            
        except requests.RequestException as e:
            logger.error(f"Failed to fetch data for {year}-{month:02d}-{day:02d}: {e}")
            return None
        except Exception as e:
            logger.error(f"Unexpected error while fetching data for {year}-{month:02d}-{day:02d}: {e}")
            return None

    def _load_single_day(self, file_path: Path) -> pd.DataFrame:
        """
        Load and process data from a single JSON file.
        
        Args:
            file_path (Path): Path to JSON file
            
        Returns:
            pd.DataFrame: Processed DataFrame
        """
        try:
            with open(file_path, 'r') as f:
                data = json.load(f)

            if 'response' in data and 'data' in data['response']:
                df = pd.DataFrame(data['response']['data'])
            else:
                logger.warning(f"Unexpected structure in file {file_path}")
                return pd.DataFrame()

            if df.empty:
                logger.warning(f"No data in file {file_path}")
                return pd.DataFrame()

            if 'subba' not in df.columns:
                logger.warning(f"'subba' column missing in {file_path}")
                return pd.DataFrame()

            # Encode sub-region codes
            df['sub_region_code'] = self.label_encoder.fit_transform(df['subba']).astype('int64')
            
            # Select and rename columns
            df = df[['period', 'sub_region_code', 'value']].copy()
            df.rename(columns={'value': 'demand', 'period': 'date'}, inplace=True)
            
            # Convert date to datetime
            df['date'] = pd.to_datetime(df['date'], utc=True)
            
            logger.info(f"Loaded {len(df)} records from {file_path}")
            return df
            
        except Exception as e:
            logger.error(f"Error loading data from {file_path}: {e}")
            return pd.DataFrame()

    def download(self) -> pd.DataFrame:
        """
        Download electricity demand data for the specified date range.
        
        Returns:
            pd.DataFrame: Combined DataFrame with all data
        """
        try:
            start = pd.to_datetime(self.config.start_date, utc=True)
            end = pd.to_datetime(self.config.end_date, utc=True)
            all_data = []

            logger.info(f"Starting data download from {start.date()} to {end.date()}")
            
            current_date = start
            total_days = (end - start).days + 1
            processed_days = 0
            
            while current_date <= end:
                year, month, day = current_date.year, current_date.month, current_date.day
                
                # Use raw_data_path for JSON files
                file_path = self.config.raw_data_path / f"hourly_demand_{year}-{month:02d}-{day:02d}.json"

                if not file_path.exists():
                    file_path = self._fetch_and_save_json(year, month, day)
                    if not file_path:
                        current_date += timedelta(days=1)
                        processed_days += 1
                        continue

                df = self._load_single_day(file_path)
                if not df.empty:
                    all_data.append(df)

                current_date += timedelta(days=1)
                processed_days += 1
                
                # Progress logging
                if processed_days % 30 == 0:
                    logger.info(f"Processed {processed_days}/{total_days} days")

            if all_data:
                final_df = pd.concat(all_data, ignore_index=True)
                
                # Sort by date
                final_df = final_df.sort_values('date').reset_index(drop=True)
                
                # Save to CSV
                final_df.to_csv(self.config.data_file, index=False)
                logger.info(f"Final dataset saved to {self.config.data_file}")
                logger.info(f"Final dataset shape: {final_df.shape}")
                logger.info(f"Date range: {final_df['date'].min()} to {final_df['date'].max()}")
                
                return final_df
            else:
                logger.warning("No data collected.")
                return pd.DataFrame()
                
        except Exception as e:
            logger.error(f"Error during data download: {e}")
            raise

# %%
try:
    config = ConfigurationManager()
    ingestion_config = config.get_data_ingestion_config()
    ingestion = DataIngestion(config=ingestion_config)
    df = ingestion.download()

except Exception as e:
    logging.info(f"An error occurred during data ingestion: {e}")
    raise
# Out:
# [2025-07-01 17:54:10,648: INFO: helpers: yaml file: config_file\config.yaml loaded successfully]
# [2025-07-01 17:54:10,652: INFO: helpers: yaml file: config_file\params.yaml loaded successfully]
# [2025-07-01 17:54:10,657: INFO: helpers: yaml file: config_file\schema.yaml loaded successfully]
# [2025-07-01 17:54:10,659: INFO: helpers: created directory at: artifacts]
# [2025-07-01 17:54:10,661: INFO: 1207651540: DataIngestion initialized with config: DataIngestionConfig(root_dir=WindowsPath('data_ingestion'), source_api='https://api.eia.gov/v2/electricity/rto/region-sub-ba-data/data/', raw_data_path=WindowsPath('artifacts/data_ingestion/raw_data'), data_file=WindowsPath('artifacts/data_ingestion/data/electricity_demand.csv'), start_date='2023-01-01', end_date='2023-12-31')]
# [2025-07-01 17:54:10,668: INFO: 1207651540: Starting data download from 2023-01-01 to 2023-12-31]
# [2025-07-01 17:54:10,673: INFO: 1207651540: Fetching data for 2023-01-01]
# [2025-07-01 17:54:13,490: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-01.json]
# [2025-07-01 17:54:13,596: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-01.json]
# [2025-07-01 17:54:13,598: INFO: 1207651540: Fetching data for 2023-01-02]
# [2025-07-01 17:54:16,753: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-02.json]
# [2025-07-01 17:54:16,775: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-02.json]
# [2025-07-01 17:54:16,775: INFO: 1207651540: Fetching data for 2023-01-03]
# [2025-07-01 17:54:19,218: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-03.json]
# [2025-07-01 17:54:19,240: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-03.json]
# [2025-07-01 17:54:19,240: INFO: 1207651540: Fetching data for 2023-01-04]
# [2025-07-01 17:54:21,957: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-04.json]
# [2025-07-01 17:54:21,972: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-04.json]
# [2025-07-01 17:54:21,972: INFO: 1207651540: Fetching data for 2023-01-05]
# [2025-07-01 17:54:24,202: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-05.json]
# [2025-07-01 17:54:24,225: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-05.json]
# [2025-07-01 17:54:24,225: INFO: 1207651540: Fetching data for 2023-01-06]
# [2025-07-01 17:54:26,202: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-06.json]
# [2025-07-01 17:54:26,233: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-06.json]
# [2025-07-01 17:54:26,236: INFO: 1207651540: Fetching data for 2023-01-07]
# [2025-07-01 17:55:31,232: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-07.json]
# [2025-07-01 17:55:31,260: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-07.json]
# [2025-07-01 17:55:31,262: INFO: 1207651540: Fetching data for 2023-01-08]
# [2025-07-01 17:55:34,224: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-08.json]
# [2025-07-01 17:55:34,247: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-08.json]
# [2025-07-01 17:55:34,249: INFO: 1207651540: Fetching data for 2023-01-09]
# [2025-07-01 17:55:36,806: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-09.json]
# [2025-07-01 17:55:36,827: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-09.json]
# [2025-07-01 17:55:36,829: INFO: 1207651540: Fetching data for 2023-01-10]
# [2025-07-01 17:55:40,069: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-10.json]
# [2025-07-01 17:55:40,089: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-10.json]
# [2025-07-01 17:55:40,092: INFO: 1207651540: Fetching data for 2023-01-11]
# [2025-07-01 17:55:43,149: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-11.json]
# [2025-07-01 17:55:43,168: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-11.json]
# [2025-07-01 17:55:43,170: INFO: 1207651540: Fetching data for 2023-01-12]
# [2025-07-01 17:55:46,350: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-12.json]
# [2025-07-01 17:55:46,372: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-12.json]
# [2025-07-01 17:55:46,376: INFO: 1207651540: Fetching data for 2023-01-13]
# [2025-07-01 17:55:50,202: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-13.json]
# [2025-07-01 17:55:50,232: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-13.json]
# [2025-07-01 17:55:50,234: INFO: 1207651540: Fetching data for 2023-01-14]
# [2025-07-01 17:55:53,658: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-14.json]
# [2025-07-01 17:55:53,678: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-14.json]
# [2025-07-01 17:55:53,680: INFO: 1207651540: Fetching data for 2023-01-15]
# [2025-07-01 17:55:56,806: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-15.json]
# [2025-07-01 17:55:56,830: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-15.json]
# [2025-07-01 17:55:56,831: INFO: 1207651540: Fetching data for 2023-01-16]
# [2025-07-01 17:56:00,907: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-16.json]
# [2025-07-01 17:56:00,929: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-16.json]
# [2025-07-01 17:56:00,930: INFO: 1207651540: Fetching data for 2023-01-17]
# [2025-07-01 17:56:02,961: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-17.json]
# [2025-07-01 17:56:02,987: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-17.json]
# [2025-07-01 17:56:02,989: INFO: 1207651540: Fetching data for 2023-01-18]
# [2025-07-01 17:56:05,602: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-18.json]
# [2025-07-01 17:56:05,626: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-18.json]
# [2025-07-01 17:56:05,628: INFO: 1207651540: Fetching data for 2023-01-19]
# [2025-07-01 17:56:07,418: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-19.json]
# [2025-07-01 17:56:07,447: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-19.json]
# [2025-07-01 17:56:07,450: INFO: 1207651540: Fetching data for 2023-01-20]
# [2025-07-01 17:56:09,599: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-20.json]
# [2025-07-01 17:56:09,622: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-20.json]
# [2025-07-01 17:56:09,624: INFO: 1207651540: Fetching data for 2023-01-21]
# [2025-07-01 17:56:12,333: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-21.json]
# [2025-07-01 17:56:12,356: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-21.json]
# [2025-07-01 17:56:12,359: INFO: 1207651540: Fetching data for 2023-01-22]
# [2025-07-01 17:56:14,743: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-22.json]
# [2025-07-01 17:56:14,767: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-22.json]
# [2025-07-01 17:56:14,770: INFO: 1207651540: Fetching data for 2023-01-23]
# [2025-07-01 17:56:20,483: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-23.json]
# [2025-07-01 17:56:20,503: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-23.json]
# [2025-07-01 17:56:20,504: INFO: 1207651540: Fetching data for 2023-01-24]
# [2025-07-01 17:56:23,294: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-24.json]
# [2025-07-01 17:56:23,316: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-24.json]
# [2025-07-01 17:56:23,317: INFO: 1207651540: Fetching data for 2023-01-25]
# [2025-07-01 17:57:02,730: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-25.json]
# [2025-07-01 17:57:02,752: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-25.json]
# [2025-07-01 17:57:02,754: INFO: 1207651540: Fetching data for 2023-01-26]
# [2025-07-01 17:57:30,877: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-26.json]
# [2025-07-01 17:57:30,912: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-26.json]
# [2025-07-01 17:57:30,914: INFO: 1207651540: Fetching data for 2023-01-27]
# [2025-07-01 17:57:32,916: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-27.json]
# [2025-07-01 17:57:32,937: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-27.json]
# [2025-07-01 17:57:32,939: INFO: 1207651540: Fetching data for 2023-01-28]
# [2025-07-01 17:57:35,064: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-28.json]
# [2025-07-01 17:57:35,089: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-28.json]
# [2025-07-01 17:57:35,090: INFO: 1207651540: Fetching data for 2023-01-29]
# [2025-07-01 17:57:36,820: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-29.json]
# [2025-07-01 17:57:36,840: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-29.json]
# [2025-07-01 17:57:36,841: INFO: 1207651540: Fetching data for 2023-01-30]
# [2025-07-01 17:57:39,043: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-30.json]
# [2025-07-01 17:57:39,068: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-30.json]
# [2025-07-01 17:57:39,070: INFO: 1207651540: Processed 30/365 days]
# [2025-07-01 17:57:39,071: INFO: 1207651540: Fetching data for 2023-01-31]
# [2025-07-01 17:57:40,908: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-01-31.json]
# [2025-07-01 17:57:40,932: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-01-31.json]
# [2025-07-01 17:57:40,934: INFO: 1207651540: Fetching data for 2023-02-01]
# [2025-07-01 17:57:43,057: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-01.json]
# [2025-07-01 17:57:43,076: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-01.json]
# [2025-07-01 17:57:43,077: INFO: 1207651540: Fetching data for 2023-02-02]
# [2025-07-01 17:57:44,886: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-02.json]
# [2025-07-01 17:57:44,905: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-02.json]
# [2025-07-01 17:57:44,907: INFO: 1207651540: Fetching data for 2023-02-03]
# [2025-07-01 17:57:46,754: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-03.json]
# [2025-07-01 17:57:46,773: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-03.json]
# [2025-07-01 17:57:46,775: INFO: 1207651540: Fetching data for 2023-02-04]
# [2025-07-01 17:57:48,705: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-04.json]
# [2025-07-01 17:57:48,726: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-04.json]
# [2025-07-01 17:57:48,727: INFO: 1207651540: Fetching data for 2023-02-05]
# [2025-07-01 17:57:50,840: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-05.json]
# [2025-07-01 17:57:50,859: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-05.json]
# [2025-07-01 17:57:50,860: INFO: 1207651540: Fetching data for 2023-02-06]
# [2025-07-01 17:57:52,954: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-06.json]
# [2025-07-01 17:57:52,973: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-06.json]
# [2025-07-01 17:57:52,974: INFO: 1207651540: Fetching data for 2023-02-07]
# [2025-07-01 17:57:54,727: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-07.json]
# [2025-07-01 17:57:54,748: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-07.json]
# [2025-07-01 17:57:54,750: INFO: 1207651540: Fetching data for 2023-02-08]
# [2025-07-01 17:57:56,824: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-08.json]
# [2025-07-01 17:57:56,850: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-08.json]
# [2025-07-01 17:57:56,851: INFO: 1207651540: Fetching data for 2023-02-09]
# [2025-07-01 17:57:58,807: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-09.json]
# [2025-07-01 17:57:58,826: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-09.json]
# [2025-07-01 17:57:58,827: INFO: 1207651540: Fetching data for 2023-02-10]
# [2025-07-01 17:58:00,758: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-10.json]
# [2025-07-01 17:58:00,777: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-10.json]
# [2025-07-01 17:58:00,778: INFO: 1207651540: Fetching data for 2023-02-11]
# [2025-07-01 17:58:02,726: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-11.json]
# [2025-07-01 17:58:02,748: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-11.json]
# [2025-07-01 17:58:02,750: INFO: 1207651540: Fetching data for 2023-02-12]
# [2025-07-01 17:58:04,603: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-12.json]
# [2025-07-01 17:58:04,624: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-12.json]
# [2025-07-01 17:58:04,627: INFO: 1207651540: Fetching data for 2023-02-13]
# [2025-07-01 17:58:06,592: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-13.json]
# [2025-07-01 17:58:06,608: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-13.json]
# [2025-07-01 17:58:06,610: INFO: 1207651540: Fetching data for 2023-02-14]
# [2025-07-01 17:58:08,540: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-14.json]
# [2025-07-01 17:58:08,563: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-14.json]
# [2025-07-01 17:58:08,566: INFO: 1207651540: Fetching data for 2023-02-15]
# [2025-07-01 17:58:10,789: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-15.json]
# [2025-07-01 17:58:10,811: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-15.json]
# [2025-07-01 17:58:10,812: INFO: 1207651540: Fetching data for 2023-02-16]
# [2025-07-01 17:58:12,602: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-16.json]
# [2025-07-01 17:58:12,624: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-16.json]
# [2025-07-01 17:58:12,625: INFO: 1207651540: Fetching data for 2023-02-17]
# [2025-07-01 17:58:16,046: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-17.json]
# [2025-07-01 17:58:16,072: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-17.json]
# [2025-07-01 17:58:16,073: INFO: 1207651540: Fetching data for 2023-02-18]
# [2025-07-01 17:58:18,074: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-18.json]
# [2025-07-01 17:58:18,104: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-18.json]
# [2025-07-01 17:58:18,107: INFO: 1207651540: Fetching data for 2023-02-19]
# [2025-07-01 17:58:20,010: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-19.json]
# [2025-07-01 17:58:20,028: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-19.json]
# [2025-07-01 17:58:20,030: INFO: 1207651540: Fetching data for 2023-02-20]
# [2025-07-01 17:58:21,857: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-20.json]
# [2025-07-01 17:58:21,880: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-20.json]
# [2025-07-01 17:58:21,882: INFO: 1207651540: Fetching data for 2023-02-21]
# [2025-07-01 17:58:24,071: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-21.json]
# [2025-07-01 17:58:24,090: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-21.json]
# [2025-07-01 17:58:24,093: INFO: 1207651540: Fetching data for 2023-02-22]
# [2025-07-01 17:58:26,090: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-22.json]
# [2025-07-01 17:58:26,107: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-22.json]
# [2025-07-01 17:58:26,108: INFO: 1207651540: Fetching data for 2023-02-23]
# [2025-07-01 17:58:27,940: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-23.json]
# [2025-07-01 17:58:27,967: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-23.json]
# [2025-07-01 17:58:27,970: INFO: 1207651540: Fetching data for 2023-02-24]
# [2025-07-01 17:58:30,143: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-24.json]
# [2025-07-01 17:58:30,165: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-24.json]
# [2025-07-01 17:58:30,166: INFO: 1207651540: Fetching data for 2023-02-25]
# [2025-07-01 17:58:32,150: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-25.json]
# [2025-07-01 17:58:32,169: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-25.json]
# [2025-07-01 17:58:32,171: INFO: 1207651540: Fetching data for 2023-02-26]
# [2025-07-01 17:58:33,995: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-26.json]
# [2025-07-01 17:58:34,014: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-26.json]
# [2025-07-01 17:58:34,017: INFO: 1207651540: Fetching data for 2023-02-27]
# [2025-07-01 17:58:36,073: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-27.json]
# [2025-07-01 17:58:36,100: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-27.json]
# [2025-07-01 17:58:36,102: INFO: 1207651540: Fetching data for 2023-02-28]
# [2025-07-01 17:58:38,144: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-02-28.json]
# [2025-07-01 17:58:38,163: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-02-28.json]
# [2025-07-01 17:58:38,164: INFO: 1207651540: Fetching data for 2023-03-01]
# [2025-07-01 17:58:40,260: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-01.json]
# [2025-07-01 17:58:40,280: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-01.json]
# [2025-07-01 17:58:40,281: INFO: 1207651540: Processed 60/365 days]
# [2025-07-01 17:58:40,283: INFO: 1207651540: Fetching data for 2023-03-02]
# [2025-07-01 17:58:42,298: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-02.json]
# [2025-07-01 17:58:42,321: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-02.json]
# [2025-07-01 17:58:42,324: INFO: 1207651540: Fetching data for 2023-03-03]
# [2025-07-01 17:58:44,076: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-03.json]
# [2025-07-01 17:58:44,098: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-03.json]
# [2025-07-01 17:58:44,101: INFO: 1207651540: Fetching data for 2023-03-04]
# [2025-07-01 17:58:46,162: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-04.json]
# [2025-07-01 17:58:46,190: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-04.json]
# [2025-07-01 17:58:46,191: INFO: 1207651540: Fetching data for 2023-03-05]
# [2025-07-01 17:58:48,052: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-05.json]
# [2025-07-01 17:58:48,077: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-05.json]
# [2025-07-01 17:58:48,079: INFO: 1207651540: Fetching data for 2023-03-06]
# [2025-07-01 17:58:49,928: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-06.json]
# [2025-07-01 17:58:49,960: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-06.json]
# [2025-07-01 17:58:49,961: INFO: 1207651540: Fetching data for 2023-03-07]
# [2025-07-01 17:58:51,764: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-07.json]
# [2025-07-01 17:58:51,787: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-07.json]
# [2025-07-01 17:58:51,789: INFO: 1207651540: Fetching data for 2023-03-08]
# [2025-07-01 17:58:53,821: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-08.json]
# [2025-07-01 17:58:53,840: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-08.json]
# [2025-07-01 17:58:53,841: INFO: 1207651540: Fetching data for 2023-03-09]
# [2025-07-01 17:58:55,908: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-09.json]
# [2025-07-01 17:58:55,931: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-09.json]
# [2025-07-01 17:58:55,934: INFO: 1207651540: Fetching data for 2023-03-10]
# [2025-07-01 17:58:58,011: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-10.json]
# [2025-07-01 17:58:58,031: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-10.json]
# [2025-07-01 17:58:58,033: INFO: 1207651540: Fetching data for 2023-03-11]
# [2025-07-01 17:58:59,913: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-11.json]
# [2025-07-01 17:58:59,931: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-11.json]
# [2025-07-01 17:58:59,932: INFO: 1207651540: Fetching data for 2023-03-12]
# [2025-07-01 17:59:01,770: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-12.json]
# [2025-07-01 17:59:01,795: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-12.json]
# [2025-07-01 17:59:01,797: INFO: 1207651540: Fetching data for 2023-03-13]
# [2025-07-01 17:59:03,596: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-13.json]
# [2025-07-01 17:59:03,619: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-13.json]
# [2025-07-01 17:59:03,621: INFO: 1207651540: Fetching data for 2023-03-14]
# [2025-07-01 17:59:05,572: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-14.json]
# [2025-07-01 17:59:05,595: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-14.json]
# [2025-07-01 17:59:05,596: INFO: 1207651540: Fetching data for 2023-03-15]
# [2025-07-01 17:59:07,626: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-15.json]
# [2025-07-01 17:59:07,657: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-15.json]
# [2025-07-01 17:59:07,660: INFO: 1207651540: Fetching data for 2023-03-16]
# [2025-07-01 17:59:10,076: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-16.json]
# [2025-07-01 17:59:10,091: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-16.json]
# [2025-07-01 17:59:10,107: INFO: 1207651540: Fetching data for 2023-03-17]
# [2025-07-01 17:59:12,123: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-17.json]
# [2025-07-01 17:59:12,139: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-17.json]
# [2025-07-01 17:59:12,139: INFO: 1207651540: Fetching data for 2023-03-18]
# [2025-07-01 17:59:13,973: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-18.json]
# [2025-07-01 17:59:14,005: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-18.json]
# [2025-07-01 17:59:14,007: INFO: 1207651540: Fetching data for 2023-03-19]
# [2025-07-01 17:59:16,288: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-19.json]
# [2025-07-01 17:59:16,304: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-19.json]
# [2025-07-01 17:59:16,318: INFO: 1207651540: Fetching data for 2023-03-20]
# [2025-07-01 17:59:18,010: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-20.json]
# [2025-07-01 17:59:18,030: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-20.json]
# [2025-07-01 17:59:18,032: INFO: 1207651540: Fetching data for 2023-03-21]
# [2025-07-01 17:59:19,957: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-21.json]
# [2025-07-01 17:59:19,973: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-21.json]
# [2025-07-01 17:59:19,973: INFO: 1207651540: Fetching data for 2023-03-22]
# [2025-07-01 17:59:22,005: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-22.json]
# [2025-07-01 17:59:22,021: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-22.json]
# [2025-07-01 17:59:22,036: INFO: 1207651540: Fetching data for 2023-03-23]
# [2025-07-01 17:59:23,974: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-23.json]
# [2025-07-01 17:59:23,989: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-23.json]
# [2025-07-01 17:59:24,005: INFO: 1207651540: Fetching data for 2023-03-24]
# [2025-07-01 17:59:25,821: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-24.json]
# [2025-07-01 17:59:25,837: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-24.json]
# [2025-07-01 17:59:25,837: INFO: 1207651540: Fetching data for 2023-03-25]
# [2025-07-01 17:59:27,557: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-25.json]
# [2025-07-01 17:59:27,580: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-25.json]
# [2025-07-01 17:59:27,585: INFO: 1207651540: Fetching data for 2023-03-26]
# [2025-07-01 17:59:29,856: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-26.json]
# [2025-07-01 17:59:29,891: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-26.json]
# [2025-07-01 17:59:29,893: INFO: 1207651540: Fetching data for 2023-03-27]
# [2025-07-01 17:59:31,907: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-27.json]
# [2025-07-01 17:59:31,922: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-27.json]
# [2025-07-01 17:59:31,922: INFO: 1207651540: Fetching data for 2023-03-28]
# [2025-07-01 17:59:33,707: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-28.json]
# [2025-07-01 17:59:33,723: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-28.json]
# [2025-07-01 17:59:33,723: INFO: 1207651540: Fetching data for 2023-03-29]
# [2025-07-01 17:59:35,438: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-29.json]
# [2025-07-01 17:59:35,457: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-29.json]
# [2025-07-01 17:59:35,457: INFO: 1207651540: Fetching data for 2023-03-30]
# [2025-07-01 17:59:37,243: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-30.json]
# [2025-07-01 17:59:37,258: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-30.json]
# [2025-07-01 17:59:37,258: INFO: 1207651540: Fetching data for 2023-03-31]
# [2025-07-01 17:59:39,738: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-03-31.json]
# [2025-07-01 17:59:39,752: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-03-31.json]
# [2025-07-01 17:59:39,752: INFO: 1207651540: Processed 90/365 days]
# [2025-07-01 17:59:39,769: INFO: 1207651540: Fetching data for 2023-04-01]
# [2025-07-01 17:59:41,621: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-01.json]
# [2025-07-01 17:59:41,660: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-01.json]
# [2025-07-01 17:59:41,660: INFO: 1207651540: Fetching data for 2023-04-02]
# [2025-07-01 17:59:44,042: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-02.json]
# [2025-07-01 17:59:44,057: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-02.json]
# [2025-07-01 17:59:44,057: INFO: 1207651540: Fetching data for 2023-04-03]
# [2025-07-01 17:59:46,289: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-03.json]
# [2025-07-01 17:59:46,312: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-03.json]
# [2025-07-01 17:59:46,312: INFO: 1207651540: Fetching data for 2023-04-04]
# [2025-07-01 17:59:48,177: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-04.json]
# [2025-07-01 17:59:48,208: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-04.json]
# [2025-07-01 17:59:48,211: INFO: 1207651540: Fetching data for 2023-04-05]
# [2025-07-01 17:59:49,943: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-05.json]
# [2025-07-01 17:59:49,959: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-05.json]
# [2025-07-01 17:59:49,959: INFO: 1207651540: Fetching data for 2023-04-06]
# [2025-07-01 17:59:51,742: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-06.json]
# [2025-07-01 17:59:51,777: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-06.json]
# [2025-07-01 17:59:51,780: INFO: 1207651540: Fetching data for 2023-04-07]
# [2025-07-01 17:59:53,640: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-07.json]
# [2025-07-01 17:59:53,655: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-07.json]
# [2025-07-01 17:59:53,655: INFO: 1207651540: Fetching data for 2023-04-08]
# [2025-07-01 17:59:56,007: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-08.json]
# [2025-07-01 17:59:56,045: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-08.json]
# [2025-07-01 17:59:56,047: INFO: 1207651540: Fetching data for 2023-04-09]
# [2025-07-01 17:59:57,904: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-09.json]
# [2025-07-01 17:59:57,925: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-09.json]
# [2025-07-01 17:59:57,925: INFO: 1207651540: Fetching data for 2023-04-10]
# [2025-07-01 18:00:02,476: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-10.json]
# [2025-07-01 18:00:02,492: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-10.json]
# [2025-07-01 18:00:02,492: INFO: 1207651540: Fetching data for 2023-04-11]
# [2025-07-01 18:00:06,092: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-11.json]
# [2025-07-01 18:00:06,131: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-11.json]
# [2025-07-01 18:00:06,137: INFO: 1207651540: Fetching data for 2023-04-12]
# [2025-07-01 18:00:08,477: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-12.json]
# [2025-07-01 18:00:08,516: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-12.json]
# [2025-07-01 18:00:08,516: INFO: 1207651540: Fetching data for 2023-04-13]
# [2025-07-01 18:00:10,744: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-13.json]
# [2025-07-01 18:00:10,784: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-13.json]
# [2025-07-01 18:00:10,784: INFO: 1207651540: Fetching data for 2023-04-14]
# [2025-07-01 18:00:14,991: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-14.json]
# [2025-07-01 18:00:15,026: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-14.json]
# [2025-07-01 18:00:15,030: INFO: 1207651540: Fetching data for 2023-04-15]
# [2025-07-01 18:00:18,143: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-15.json]
# [2025-07-01 18:00:18,192: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-15.json]
# [2025-07-01 18:00:18,194: INFO: 1207651540: Fetching data for 2023-04-16]
# [2025-07-01 18:00:20,511: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-16.json]
# [2025-07-01 18:00:20,526: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-16.json]
# [2025-07-01 18:00:20,542: INFO: 1207651540: Fetching data for 2023-04-17]
# [2025-07-01 18:00:22,375: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-17.json]
# [2025-07-01 18:00:22,391: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-17.json]
# [2025-07-01 18:00:22,391: INFO: 1207651540: Fetching data for 2023-04-18]
# [2025-07-01 18:00:24,958: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-18.json]
# [2025-07-01 18:00:24,990: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-18.json]
# [2025-07-01 18:00:24,993: INFO: 1207651540: Fetching data for 2023-04-19]
# [2025-07-01 18:00:27,111: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-19.json]
# [2025-07-01 18:00:27,127: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-19.json]
# [2025-07-01 18:00:27,140: INFO: 1207651540: Fetching data for 2023-04-20]
# [2025-07-01 18:00:29,995: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-20.json]
# [2025-07-01 18:00:30,011: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-20.json]
# [2025-07-01 18:00:30,011: INFO: 1207651540: Fetching data for 2023-04-21]
# [2025-07-01 18:00:31,873: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-21.json]
# [2025-07-01 18:00:31,915: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-21.json]
# [2025-07-01 18:00:31,921: INFO: 1207651540: Fetching data for 2023-04-22]
# [2025-07-01 18:00:34,693: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-22.json]
# [2025-07-01 18:00:34,709: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-22.json]
# [2025-07-01 18:00:34,709: INFO: 1207651540: Fetching data for 2023-04-23]
# [2025-07-01 18:00:37,478: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-23.json]
# [2025-07-01 18:00:37,493: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-23.json]
# [2025-07-01 18:00:37,493: INFO: 1207651540: Fetching data for 2023-04-24]
# [2025-07-01 18:00:39,810: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-24.json]
# [2025-07-01 18:00:39,826: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-24.json]
# [2025-07-01 18:00:39,826: INFO: 1207651540: Fetching data for 2023-04-25]
# [2025-07-01 18:00:42,325: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-25.json]
# [2025-07-01 18:00:42,343: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-25.json]
# [2025-07-01 18:00:42,343: INFO: 1207651540: Fetching data for 2023-04-26]
# [2025-07-01 18:00:44,492: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-26.json]
# [2025-07-01 18:00:44,508: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-26.json]
# [2025-07-01 18:00:44,508: INFO: 1207651540: Fetching data for 2023-04-27]
# [2025-07-01 18:00:46,613: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-27.json]
# [2025-07-01 18:00:46,623: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-27.json]
# [2025-07-01 18:00:46,638: INFO: 1207651540: Fetching data for 2023-04-28]
# [2025-07-01 18:00:49,812: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-28.json]
# [2025-07-01 18:00:49,842: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-28.json]
# [2025-07-01 18:00:49,844: INFO: 1207651540: Fetching data for 2023-04-29]
# [2025-07-01 18:00:51,695: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-29.json]
# [2025-07-01 18:00:51,719: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-29.json]
# [2025-07-01 18:00:51,719: INFO: 1207651540: Fetching data for 2023-04-30]
# [2025-07-01 18:00:53,991: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-04-30.json]
# [2025-07-01 18:00:54,019: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-04-30.json]
# [2025-07-01 18:00:54,025: INFO: 1207651540: Processed 120/365 days]
# [2025-07-01 18:00:54,028: INFO: 1207651540: Fetching data for 2023-05-01]
# [2025-07-01 18:00:55,830: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-05-01.json]
# [2025-07-01 18:00:55,845: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-05-01.json]
# [2025-07-01 18:00:55,845: INFO: 1207651540: Fetching data for 2023-05-02]
# [2025-07-01 18:00:58,631: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-05-02.json]
# [2025-07-01 18:00:58,661: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-05-02.json]
# [2025-07-01 18:00:58,663: INFO: 1207651540: Fetching data for 2023-05-03]
# [2025-07-01 18:01:00,969: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-05-03.json]
# [2025-07-01 18:01:00,979: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-05-03.json]
# [2025-07-01 18:01:00,979: INFO: 1207651540: Fetching data for 2023-05-04]
# [2025-07-01 18:01:03,259: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-05-04.json]
# [2025-07-01 18:01:03,274: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-05-04.json]
# [2025-07-01 18:01:03,274: INFO: 1207651540: Fetching data for 2023-05-05]
# [2025-07-01 18:01:05,828: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-05-05.json]
# [2025-07-01 18:01:05,844: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-05-05.json]
# [2025-07-01 18:01:05,844: INFO: 1207651540: Fetching data for 2023-05-06]
# [2025-07-01 18:01:07,944: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-05-06.json]
# [2025-07-01 18:01:07,968: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-05-06.json]
# [2025-07-01 18:01:07,968: INFO: 1207651540: Fetching data for 2023-05-07]
# [2025-07-01 18:01:10,493: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-05-07.json]
# [2025-07-01 18:01:10,509: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-05-07.json]
# [2025-07-01 18:01:10,509: INFO: 1207651540: Fetching data for 2023-05-08]
# [2025-07-01 18:01:12,611: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-05-08.json]
# [2025-07-01 18:01:12,627: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-05-08.json]
# [2025-07-01 18:01:12,627: INFO: 1207651540: Fetching data for 2023-05-09]
# [2025-07-01 18:01:15,646: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-05-09.json]
# [2025-07-01 18:01:15,670: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-05-09.json]
# [2025-07-01 18:01:15,674: INFO: 1207651540: Fetching data for 2023-05-10]
# [2025-07-01 18:01:17,629: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-05-10.json]
# [2025-07-01 18:01:17,661: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-05-10.json]
# [2025-07-01 18:01:17,663: INFO: 1207651540: Fetching data for 2023-05-11]
# [2025-07-01 18:01:19,849: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-05-11.json]
# [2025-07-01 18:01:19,897: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-05-11.json]
# [2025-07-01 18:01:19,901: INFO: 1207651540: Fetching data for 2023-05-12]
# [2025-07-01 18:01:21,848: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-05-12.json]
# [2025-07-01 18:01:21,864: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-05-12.json]
# [2025-07-01 18:01:21,880: INFO: 1207651540: Fetching data for 2023-05-13]
# [2025-07-01 18:01:24,128: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-05-13.json]
# [2025-07-01 18:01:24,152: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-05-13.json]
# [2025-07-01 18:01:24,152: INFO: 1207651540: Fetching data for 2023-05-14]
# [2025-07-01 18:01:26,128: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-05-14.json]
# [2025-07-01 18:01:26,144: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-05-14.json]
# [2025-07-01 18:01:26,144: INFO: 1207651540: Fetching data for 2023-05-15]
# [2025-07-01 18:01:28,082: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-05-15.json]
# [2025-07-01 18:01:28,097: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-05-15.json]
# [2025-07-01 18:01:28,097: INFO: 1207651540: Fetching data for 2023-05-16]
# [2025-07-01 18:01:30,181: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-05-16.json]
# [2025-07-01 18:01:30,204: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-05-16.json]
# [2025-07-01 18:01:30,207: INFO: 1207651540: Fetching data for 2023-05-17]
# [2025-07-01 18:01:31,965: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-05-17.json]
# [2025-07-01 18:01:32,004: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-05-17.json]
# [2025-07-01 18:01:32,010: INFO: 1207651540: Fetching data for 2023-05-18]
# [2025-07-01 18:01:34,817: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-05-18.json]
# [2025-07-01 18:01:34,860: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-05-18.json]
# [2025-07-01 18:01:34,864: INFO: 1207651540: Fetching data for 2023-05-19]
# [2025-07-01 18:01:36,948: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-05-19.json]
# [2025-07-01 18:01:36,980: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-05-19.json]
# [2025-07-01 18:01:36,983: INFO: 1207651540: Fetching data for 2023-05-20]
# [2025-07-01 18:01:39,032: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-05-20.json]
# [2025-07-01 18:01:39,047: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-05-20.json]
# [2025-07-01 18:01:39,047: INFO: 1207651540: Fetching data for 2023-05-21]
# [2025-07-01 18:01:41,266: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-05-21.json]
# [2025-07-01 18:01:41,298: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-05-21.json]
# [2025-07-01 18:01:41,298: INFO: 1207651540: Fetching data for 2023-05-22]
# [2025-07-01 18:01:43,383: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-05-22.json]
# ...
# [2025-07-01 18:09:00,204: INFO: 1207651540: Fetching data for 2023-11-15]
# [2025-07-01 18:09:02,229: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-11-15.json]
# [2025-07-01 18:09:02,251: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-11-15.json]
# [2025-07-01 18:09:02,254: INFO: 1207651540: Fetching data for 2023-11-16]
# [2025-07-01 18:09:03,981: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-11-16.json]
# [2025-07-01 18:09:04,001: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-11-16.json]
# [2025-07-01 18:09:04,004: INFO: 1207651540: Fetching data for 2023-11-17]
# [2025-07-01 18:09:05,769: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-11-17.json]
# [2025-07-01 18:09:05,795: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-11-17.json]
# [2025-07-01 18:09:05,797: INFO: 1207651540: Fetching data for 2023-11-18]
# [2025-07-01 18:09:08,068: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-11-18.json]
# [2025-07-01 18:09:08,090: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-11-18.json]
# [2025-07-01 18:09:08,092: INFO: 1207651540: Fetching data for 2023-11-19]
# [2025-07-01 18:09:09,827: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-11-19.json]
# [2025-07-01 18:09:09,849: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-11-19.json]
# [2025-07-01 18:09:09,851: INFO: 1207651540: Fetching data for 2023-11-20]
# [2025-07-01 18:09:12,797: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-11-20.json]
# [2025-07-01 18:09:12,817: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-11-20.json]
# [2025-07-01 18:09:12,819: INFO: 1207651540: Fetching data for 2023-11-21]
# [2025-07-01 18:09:15,099: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-11-21.json]
# [2025-07-01 18:09:15,125: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-11-21.json]
# [2025-07-01 18:09:15,128: INFO: 1207651540: Fetching data for 2023-11-22]
# [2025-07-01 18:09:16,926: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-11-22.json]
# [2025-07-01 18:09:16,952: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-11-22.json]
# [2025-07-01 18:09:16,956: INFO: 1207651540: Fetching data for 2023-11-23]
# [2025-07-01 18:09:18,895: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-11-23.json]
# [2025-07-01 18:09:18,916: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-11-23.json]
# [2025-07-01 18:09:18,918: INFO: 1207651540: Fetching data for 2023-11-24]
# [2025-07-01 18:09:20,891: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-11-24.json]
# [2025-07-01 18:09:20,922: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-11-24.json]
# [2025-07-01 18:09:20,924: INFO: 1207651540: Fetching data for 2023-11-25]
# [2025-07-01 18:09:22,885: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-11-25.json]
# [2025-07-01 18:09:22,906: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-11-25.json]
# [2025-07-01 18:09:22,907: INFO: 1207651540: Fetching data for 2023-11-26]
# [2025-07-01 18:09:25,141: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-11-26.json]
# [2025-07-01 18:09:25,170: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-11-26.json]
# [2025-07-01 18:09:25,172: INFO: 1207651540: Processed 330/365 days]
# [2025-07-01 18:09:25,174: INFO: 1207651540: Fetching data for 2023-11-27]
# [2025-07-01 18:09:27,210: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-11-27.json]
# [2025-07-01 18:09:27,241: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-11-27.json]
# [2025-07-01 18:09:27,241: INFO: 1207651540: Fetching data for 2023-11-28]
# [2025-07-01 18:09:29,133: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-11-28.json]
# [2025-07-01 18:09:29,148: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-11-28.json]
# [2025-07-01 18:09:29,164: INFO: 1207651540: Fetching data for 2023-11-29]
# [2025-07-01 18:09:31,080: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-11-29.json]
# [2025-07-01 18:09:31,105: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-11-29.json]
# [2025-07-01 18:09:31,108: INFO: 1207651540: Fetching data for 2023-11-30]
# [2025-07-01 18:09:32,900: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-11-30.json]
# [2025-07-01 18:09:32,903: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-11-30.json]
# [2025-07-01 18:09:32,919: INFO: 1207651540: Fetching data for 2023-12-01]
# [2025-07-01 18:09:34,690: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-01.json]
# [2025-07-01 18:09:34,714: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-01.json]
# [2025-07-01 18:09:34,714: INFO: 1207651540: Fetching data for 2023-12-02]
# [2025-07-01 18:09:36,720: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-02.json]
# [2025-07-01 18:09:36,736: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-02.json]
# [2025-07-01 18:09:36,736: INFO: 1207651540: Fetching data for 2023-12-03]
# [2025-07-01 18:09:39,507: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-03.json]
# [2025-07-01 18:09:39,546: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-03.json]
# [2025-07-01 18:09:39,556: INFO: 1207651540: Fetching data for 2023-12-04]
# [2025-07-01 18:09:41,740: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-04.json]
# [2025-07-01 18:09:41,774: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-04.json]
# [2025-07-01 18:09:41,776: INFO: 1207651540: Fetching data for 2023-12-05]
# [2025-07-01 18:09:43,590: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-05.json]
# [2025-07-01 18:09:43,620: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-05.json]
# [2025-07-01 18:09:43,624: INFO: 1207651540: Fetching data for 2023-12-06]
# [2025-07-01 18:09:45,722: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-06.json]
# [2025-07-01 18:09:45,737: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-06.json]
# [2025-07-01 18:09:45,737: INFO: 1207651540: Fetching data for 2023-12-07]
# [2025-07-01 18:09:47,604: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-07.json]
# [2025-07-01 18:09:47,620: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-07.json]
# [2025-07-01 18:09:47,620: INFO: 1207651540: Fetching data for 2023-12-08]
# [2025-07-01 18:09:49,406: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-08.json]
# [2025-07-01 18:09:49,429: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-08.json]
# [2025-07-01 18:09:49,430: INFO: 1207651540: Fetching data for 2023-12-09]
# [2025-07-01 18:09:51,803: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-09.json]
# [2025-07-01 18:09:51,835: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-09.json]
# [2025-07-01 18:09:51,839: INFO: 1207651540: Fetching data for 2023-12-10]
# [2025-07-01 18:09:53,620: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-10.json]
# [2025-07-01 18:09:53,641: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-10.json]
# [2025-07-01 18:09:53,641: INFO: 1207651540: Fetching data for 2023-12-11]
# [2025-07-01 18:09:55,426: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-11.json]
# [2025-07-01 18:09:55,461: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-11.json]
# [2025-07-01 18:09:55,463: INFO: 1207651540: Fetching data for 2023-12-12]
# [2025-07-01 18:09:57,340: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-12.json]
# [2025-07-01 18:09:57,373: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-12.json]
# [2025-07-01 18:09:57,376: INFO: 1207651540: Fetching data for 2023-12-13]
# [2025-07-01 18:09:59,537: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-13.json]
# [2025-07-01 18:09:59,584: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-13.json]
# [2025-07-01 18:09:59,584: INFO: 1207651540: Fetching data for 2023-12-14]
# [2025-07-01 18:10:26,841: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-14.json]
# [2025-07-01 18:10:26,856: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-14.json]
# [2025-07-01 18:10:26,856: INFO: 1207651540: Fetching data for 2023-12-15]
# [2025-07-01 18:10:51,226: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-15.json]
# [2025-07-01 18:10:51,242: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-15.json]
# [2025-07-01 18:10:51,242: INFO: 1207651540: Fetching data for 2023-12-16]
# [2025-07-01 18:11:03,525: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-16.json]
# [2025-07-01 18:11:03,558: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-16.json]
# [2025-07-01 18:11:03,563: INFO: 1207651540: Fetching data for 2023-12-17]
# [2025-07-01 18:11:06,176: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-17.json]
# [2025-07-01 18:11:06,192: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-17.json]
# [2025-07-01 18:11:06,208: INFO: 1207651540: Fetching data for 2023-12-18]
# [2025-07-01 18:11:08,726: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-18.json]
# [2025-07-01 18:11:08,742: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-18.json]
# [2025-07-01 18:11:08,742: INFO: 1207651540: Fetching data for 2023-12-19]
# [2025-07-01 18:11:11,231: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-19.json]
# [2025-07-01 18:11:11,262: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-19.json]
# [2025-07-01 18:11:11,262: INFO: 1207651540: Fetching data for 2023-12-20]
# [2025-07-01 18:11:14,193: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-20.json]
# [2025-07-01 18:11:14,209: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-20.json]
# [2025-07-01 18:11:14,209: INFO: 1207651540: Fetching data for 2023-12-21]
# [2025-07-01 18:11:16,226: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-21.json]
# [2025-07-01 18:11:16,250: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-21.json]
# [2025-07-01 18:11:16,251: INFO: 1207651540: Fetching data for 2023-12-22]
# [2025-07-01 18:11:19,324: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-22.json]
# [2025-07-01 18:11:19,349: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-22.json]
# [2025-07-01 18:11:19,352: INFO: 1207651540: Fetching data for 2023-12-23]
# [2025-07-01 18:11:21,960: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-23.json]
# [2025-07-01 18:11:21,976: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-23.json]
# [2025-07-01 18:11:21,976: INFO: 1207651540: Fetching data for 2023-12-24]
# [2025-07-01 18:11:24,543: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-24.json]
# [2025-07-01 18:11:24,560: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-24.json]
# [2025-07-01 18:11:24,560: INFO: 1207651540: Fetching data for 2023-12-25]
# [2025-07-01 18:11:26,410: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-25.json]
# [2025-07-01 18:11:26,444: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-25.json]
# [2025-07-01 18:11:26,446: INFO: 1207651540: Fetching data for 2023-12-26]
# [2025-07-01 18:11:28,594: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-26.json]
# [2025-07-01 18:11:28,610: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-26.json]
# [2025-07-01 18:11:28,625: INFO: 1207651540: Processed 360/365 days]
# [2025-07-01 18:11:28,627: INFO: 1207651540: Fetching data for 2023-12-27]
# [2025-07-01 18:11:31,311: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-27.json]
# [2025-07-01 18:11:31,354: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-27.json]
# [2025-07-01 18:11:31,361: INFO: 1207651540: Fetching data for 2023-12-28]
# [2025-07-01 18:11:33,916: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-28.json]
# [2025-07-01 18:11:33,949: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-28.json]
# [2025-07-01 18:11:33,952: INFO: 1207651540: Fetching data for 2023-12-29]
# [2025-07-01 18:11:37,316: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-29.json]
# [2025-07-01 18:11:37,327: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-29.json]
# [2025-07-01 18:11:37,327: INFO: 1207651540: Fetching data for 2023-12-30]
# [2025-07-01 18:11:40,811: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-30.json]
# [2025-07-01 18:11:40,827: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-30.json]
# [2025-07-01 18:11:40,827: INFO: 1207651540: Fetching data for 2023-12-31]
# [2025-07-01 18:11:43,578: INFO: 1207651540: Saved data to artifacts\data_ingestion\raw_data\hourly_demand_2023-12-31.json]
# [2025-07-01 18:11:43,595: INFO: 1207651540: Loaded 275 records from artifacts\data_ingestion\raw_data\hourly_demand_2023-12-31.json]
# [2025-07-01 18:11:44,161: INFO: 1207651540: Final dataset saved to artifacts\data_ingestion\data\electricity_demand.csv]
# [2025-07-01 18:11:44,161: INFO: 1207651540: Final dataset shape: (100100, 3)]
# [2025-07-01 18:11:44,161: INFO: 1207651540: Date range: 2023-01-01 00:00:00+00:00 to 2024-01-01 00:00:00+00:00]
