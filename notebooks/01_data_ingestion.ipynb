# %%
import os
import sys

# %%
os.chdir('../')

# %%
sys.path.append(os.path.join(os.getcwd(), "src"))

# %%
from electron.utils.helpers import *
from electron.constants import *
from electron.utils.exception import *
from electron import logger

# %%
from pathlib import Path
from dataclasses import dataclass
from datetime import datetime, timedelta

# %%
@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    elec_api: str
    wx_api: str
    elec_raw_data: Path
    wx_raw_data: Path
    data_file: Path
    start_date: str
    end_date: str

# %%
class ConfigurationManager:
    def __init__(self, 
                 config_filepath=CONFIG_PATH,
                 params_filepath=PARAMS_PATH,
                 schema_filepath=SCHEMA_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        if schema_filepath.exists():
            self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion
        params = self.params.dates

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir=Path(config.root_dir),
            elec_api=config.elec_api,
            wx_api=config.wx_api,
            elec_raw_data=Path(config.elec_raw_data),
            wx_raw_data=Path(config.wx_raw_data),
            data_file=Path(config.data_file),
            start_date=params.start_date,
            end_date=params.end_date
        )

        return data_ingestion_config

# %%
import pandas as pd
import requests
import json
from datetime import datetime, timedelta
import openmeteo_requests
import requests_cache
from retry_requests import retry
from electron import logger
from pathlib import Path

cache_session = requests_cache.CachedSession('.cache', expire_after=3600)
retry_session = retry(cache_session, retries=5, backoff_factor=0.2)

class DataIngestion:
    def __init__(self, config):
        self.config = config
        self.openmeteo = openmeteo_requests.Client(session=retry_session)

    def _elec_get_api_url(self, year, month, day):
        return self.config.elec_api, {
            "frequency": "hourly",
            "data[0]": "value",
            "sort[0][column]": "period", 
            "sort[0][direction]": "desc",
            "facets[parent][0]": "NYIS",
            "offset": 0, 
            "length": 5000,
            "start": f"{year}-{month:02d}-{day:02d}",
            "end": (datetime(year, month, day) + timedelta(days=1)).strftime("%Y-%m-%d"),
            "api_key": 'dqRq8VpXSoyUrCbrPhuYFxGl6Rul9kmVcRshZ98c'
        }

    def _wx_get_api_url(self, start_date, end_date):
        return self.config.wx_api, {
            "latitude": 40.7128,
            "longitude": -74.0060,
            "start_date": start_date.strftime("%Y-%m-%d"),
            "end_date": end_date.strftime("%Y-%m-%d"),
            "hourly": ["temperature_2m", "weather_code",
            "relative_humidity_2m", "wind_speed_10m"],
            "timeformat": "unixtime",
            "timezone": "America/New_York"
        }

    def _fetch_data(self, data_type, *args):
        """Generic fetch method for both electricity and weather data"""
        try:
            if data_type == "electricity":
                year, month, day = args
                url, params = self._elec_get_api_url(year, month, day)
                response = requests.get(url, params=params)
                response.raise_for_status()
                data = response.json()
                
                create_directories([self.config.elec_raw_data])
                file_path = self.config.elec_raw_data / f"hourly_demand_{year}-{month:02d}-{day:02d}.json"
                save_json(file_path, data)
                
                # Load and return DataFrame
                if 'response' in data and 'data' in data['response']:
                    return pd.DataFrame(data['response']['data'])
                
            elif data_type == "weather":
                start_date, end_date = args
                url, params = self._wx_get_api_url(start_date, end_date)
                responses = self.openmeteo.weather_api(url, params=params)
                response = responses[0]
                
                hourly = response.Hourly()
                hourly_data = {
                    "date": pd.date_range(
                        start=pd.to_datetime(hourly.Time(), unit="s", utc=True),
                        end=pd.to_datetime(hourly.TimeEnd(), unit="s", utc=True),
                        freq=pd.Timedelta(seconds=hourly.Interval()), inclusive="left"
                    ),
                    "temperature_2m": hourly.Variables(0).ValuesAsNumpy(),
                    "weather_code": hourly.Variables(1).ValuesAsNumpy(),
                    "relative_humidity_2m": hourly.Variables(2).ValuesAsNumpy(),
                    "wind_speed_10m": hourly.Variables(3).ValuesAsNumpy()
                }
                
                df = pd.DataFrame(data=hourly_data)
                create_directories([self.config.wx_raw_data])
                file_path = self.config.wx_raw_data / f"weather_data_{start_date.strftime('%Y-%m-%d')}_to_{end_date.strftime('%Y-%m-%d')}.csv"
                df.to_csv(file_path, index=False)
                return df
                
            return pd.DataFrame()
            
        except Exception as e:
            logger.error(f"Error fetching {data_type} data: {e}")
            return pd.DataFrame()

    def _load_existing_data(self, data_type, *args):
        """Load existing data if files exist"""
        try:
            if data_type == "electricity":
                year, month, day = args
                file_path = self.config.elec_raw_data / f"hourly_demand_{year}-{month:02d}-{day:02d}.json"
                if file_path.exists():
                    data = load_json(file_path)
                    if 'response' in data and 'data' in data['response']:
                        return pd.DataFrame(data['response']['data'])
                        
            elif data_type == "weather":
                start_date, end_date = args
                file_path = self.config.wx_raw_data / f"weather_data_{start_date.strftime('%Y-%m-%d')}_to_{end_date.strftime('%Y-%m-%d')}.csv"
                if file_path.exists():
                    return pd.read_csv(file_path)
                    
            return pd.DataFrame()
            
        except Exception as e:
            logger.error(f"Error loading {data_type} data: {e}")
            return pd.DataFrame()

    def download(self) -> pd.DataFrame:
        """Download electricity and weather data, merge and save"""
        try:
            start = pd.to_datetime(self.config.start_date, utc=True)
            end = pd.to_datetime(self.config.end_date, utc=True)
            
            # Get electricity data
            elec_data = []
            current_date = start
            while current_date <= end:
                year, month, day = current_date.year, current_date.month, current_date.day
                
                # Try loading existing data first
                df = self._load_existing_data("electricity", year, month, day)
                if df.empty:
                    df = self._fetch_data("electricity", year, month, day)
                
                if not df.empty:
                    elec_data.append(df)
                current_date += timedelta(days=1)
            
            # Get weather data
            wx_df = self._load_existing_data("weather", start, end)
            if wx_df.empty:
                wx_df = self._fetch_data("weather", start, end)
            
            # Combine and save
            if elec_data:
                elec_df = pd.concat(elec_data, ignore_index=True)
                
                if not wx_df.empty:
                    # Simple merge on date
                    if 'period' in elec_df.columns:
                        elec_df['date'] = pd.to_datetime(elec_df['period'], utc=True)
                    if 'date' in wx_df.columns:
                        wx_df['date'] = pd.to_datetime(wx_df['date'], utc=True)
                    
                    combined_df = pd.merge(elec_df, wx_df, on="date", how="inner")
                else:
                    combined_df = elec_df
                
                # Save final data
                create_directories([self.config.data_file.parent])
                combined_df.to_csv(self.config.data_file, index=False)
                logger.info(f"Dataset saved to {self.config.data_file}, shape: {combined_df.shape}")
                return combined_df
            
            return pd.DataFrame()
            
        except Exception as e:
            logger.error(f"Error during download: {e}")
            raise

# %%
try:
    config = ConfigurationManager()
    ingestion_config = config.get_data_ingestion_config()
    ingestion = DataIngestion(config=ingestion_config)
    df = ingestion.download()

except Exception as e:
    raise CustomException(str(e), sys)
# Out:
# [2025-07-04 19:38:02,128: INFO: helpers: yaml file: config_file\config.yaml loaded successfully]
# [2025-07-04 19:38:02,128: INFO: helpers: yaml file: config_file\params.yaml loaded successfully]
# [2025-07-04 19:38:02,135: INFO: helpers: yaml file: config_file\schema.yaml loaded successfully]
# [2025-07-04 19:38:02,135: INFO: helpers: created directory at: artifacts]
# [2025-07-04 19:38:02,135: INFO: helpers: created directory at: data_ingestion]
# [2025-07-04 19:38:06,010: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:38:06,026: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-01.json]
# [2025-07-04 19:38:09,252: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:38:09,269: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-02.json]
# [2025-07-04 19:38:12,800: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:38:12,815: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-03.json]
# [2025-07-04 19:38:16,053: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:38:16,053: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-04.json]
# [2025-07-04 19:38:19,285: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:38:19,286: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-05.json]
# [2025-07-04 19:38:22,487: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:38:22,487: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-06.json]
# [2025-07-04 19:38:25,241: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:38:25,253: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-07.json]
# [2025-07-04 19:38:28,254: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:38:28,270: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-08.json]
# [2025-07-04 19:38:31,387: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:38:31,387: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-09.json]
# [2025-07-04 19:38:34,125: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:38:34,131: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-10.json]
# [2025-07-04 19:38:36,787: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:38:36,787: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-11.json]
# [2025-07-04 19:38:40,454: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:38:40,472: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-12.json]
# [2025-07-04 19:38:43,088: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:38:43,088: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-13.json]
# [2025-07-04 19:38:46,029: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:38:46,035: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-14.json]
# [2025-07-04 19:38:48,855: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:38:48,871: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-15.json]
# [2025-07-04 19:38:52,304: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:38:52,304: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-16.json]
# [2025-07-04 19:38:55,537: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:38:55,538: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-17.json]
# [2025-07-04 19:38:58,672: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:38:58,688: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-18.json]
# [2025-07-04 19:39:01,431: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:39:01,438: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-19.json]
# [2025-07-04 19:39:04,572: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:39:04,588: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-20.json]
# [2025-07-04 19:39:09,688: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:39:09,688: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-21.json]
# [2025-07-04 19:39:13,197: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:39:13,197: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-22.json]
# [2025-07-04 19:39:17,156: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:39:17,172: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-23.json]
# [2025-07-04 19:39:20,690: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:39:20,706: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-24.json]
# [2025-07-04 19:39:25,073: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:39:25,073: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-25.json]
# [2025-07-04 19:39:29,124: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:39:29,142: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-26.json]
# [2025-07-04 19:39:33,240: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:39:33,240: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-27.json]
# [2025-07-04 19:39:37,041: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:39:37,041: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-28.json]
# [2025-07-04 19:39:41,991: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:39:41,991: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-29.json]
# [2025-07-04 19:39:47,142: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:39:47,142: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-30.json]
# [2025-07-04 19:39:53,158: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:39:53,158: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-01-31.json]
# [2025-07-04 19:39:58,376: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:39:58,376: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-02-01.json]
# [2025-07-04 19:40:03,942: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:40:03,959: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-02-02.json]
# [2025-07-04 19:40:10,259: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:40:10,259: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-02-03.json]
# [2025-07-04 19:40:16,481: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:40:16,482: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-02-04.json]
# [2025-07-04 19:40:21,544: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:40:21,544: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-02-05.json]
# [2025-07-04 19:40:26,511: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:40:26,511: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-02-06.json]
# [2025-07-04 19:40:31,261: INFO: helpers: created directory at: artifacts\data_ingestion\raw\elec_data]
# [2025-07-04 19:40:31,279: INFO: helpers: json file saved at: artifacts\data_ingestion\raw\elec_data\hourly_demand_2023-02